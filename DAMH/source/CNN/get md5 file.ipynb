# %%
# Import hashlib library (md5 method is part of it)
import hashlib
import pandas as pd
import numpy as np
import time
import os
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.preprocessing.text import Tokenizer, one_hot
from keras.preprocessing.sequence import pad_sequences

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# /home/amc/miniconda3/envs/venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/amc/miniconda3/envs/venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/amc/miniconda3/envs/venv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from pathlib import Path
#DirectoryMove = 'All_2001/virus'
DirectoryMove = '/home/amc/Documents/ChienND/Data_AI/DataAI_1604/Virus/Error'
import ntpath
input_dir = Path('/home/amc/Documents/ChienND/Data_AI/DataAI_1604/Virus/EmulCode')
#input_dir = Path('ALL_NEW/virus/2020')
data_files = input_dir.glob('**/*.asm')
bRet = False
i=0
for file in data_files:
    if i == 13:
        break
    fileName = ntpath.basename(file)
    os.rename(file, DirectoryMove+'/'+fileName)
    i+=1

# %%
import os
MD5FullFile= ["1111111111111111111111111111111"]
file_list_clean = os.listdir('H:/DoAnTotNghiep/DAMH/data_crawl/sontdc_data_js/clean_js')
file_list_virus = os.listdir('H:/DoAnTotNghiep/DAMH/data_crawl/sontdc_data_js/virus_js')
DirectoryClean = 'H:/DoAnTotNghiep/DAMH/data_crawl/sontdc_data_js/clean_js'
DirectoryVirus = 'H:/DoAnTotNghiep/DAMH/data_crawl/sontdc_data_js/virus_js'
bRet = False
i=0
for b in range(len(file_list_clean)):
    with open(DirectoryClean+'/'+file_list_clean[i], 'r',encoding='utf-8') as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b8270467f648> in <module>
#      12         data = file_to_check.read()
#      13         # pipe contents of the file through
# ---> 14         md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
#      15         file_to_check.close()
#      16     for md5 in MD5FullFile:
#
# NameError: name 'hashlib' is not defined

# %%
len(MD5FullFile )
# Out:
# 33084

# %%
import ntpath
DirectoryMove = 'Move/trungdatavirus'
file_list_clean = os.listdir('ALL_NEW/virus/2020')
DirectoryClean = 'ALL_NEW/virus/2020'
bRet = False
i=0
for b in range(len(file_list_clean)):
    with open(DirectoryClean+'/'+file_list_clean[i], 'r',encoding='utf-8') as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(DirectoryClean+'/'+file_list_clean[i])
        os.rename(DirectoryClean+'/'+file_list_clean[i], DirectoryMove+'/'+file_list_clean[i])
        #os.remove(file)
        bRet = False
    i+=1
# Out:
# ALL_NEW/virus/2020/2020_4 (33)..asm2020
# ALL_NEW/virus/2020/2020_5 (41).asm2020
# ALL_NEW/virus/2020/2020_5 (84).asm2020
# ALL_NEW/virus/2020/2020_5 (11).asm2020

# %%
import ntpath
DirectoryMove = 'Move/trungdataclean'
file_list_clean = os.listdir('All_2001/clean')
DirectoryClean = 'All_2001/clean'
bRet = False
i=0
for b in range(len(file_list_clean)):
    with open(DirectoryClean+'/'+file_list_clean[i], 'r',encoding='utf-8') as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(DirectoryClean+'/'+file_list_clean[i])
        os.rename(DirectoryClean+'/'+file_list_clean[i], DirectoryMove+'/'+file_list_clean[i])
        #os.remove(file)
        bRet = False
    i+=1
# Out:
# All_2001/clean/uninst_129.asm1
# All_2001/clean/Default.SFX.asm3_
# All_2001/clean/UNINST_Uninstall_S_F786B9E0489941A08010A41A5A4D278C_1.asm20_
# All_2001/clean/_SHCT_FineReader_1_3E36FF39D91C47F89277D9CEE94684B9_9.asm10
# All_2001/clean/mtk_etw_log.asm20_
# All_2001/clean/uninst_33.asm20_
# All_2001/clean/Default_8.SFX.asm20
# All_2001/clean/unins000_39.asm20_
# All_2001/clean/TopSMS.asm30_
# All_2001/clean/bkavservices.asm1
# All_2001/clean/uninstall_404.asm20
# All_2001/clean/UnPKCSPlugin.asm1
# All_2001/clean/764_5.asm1
# All_2001/clean/icon_finereader_1.asm1
# All_2001/clean/sndvol32.asm20
# All_2001/clean/Uninstall_745.asm20
# All_2001/clean/UltraViewer_setup_6.2_vi_1.asm10
# All_2001/clean/newshortcut4_2ef84684ede247d3b23949a2e92e6901_3.asm20
# All_2001/clean/NewShortcut5_0BC7F28066A94E17A5E9A5129A95B61C_1.asm10
# All_2001/clean/NewShortcut71_34315166F1D4465C9599E3A6629052BE.asm1
# All_2001/clean/vnTools114.asm1
# All_2001/clean/downloader.asm20
# ...

# %%
import ntpath
DirectoryMove = 'Move/trungdataclean'
file_list_clean = os.listdir('All_2001/clean')
DirectoryClean = 'All_2001/clean'
bRet = False
i=0
for b in range(len(file_list_virus)):
    with open(DirectoryClean+'/'+file_list_clean[i], 'r',encoding='utf-8') as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(DirectoryVirus+'/'+file_list_virus[i])
        os.rename(DirectoryVirus+'/'+file_list_virus[i], DirectoryMove+'/'+file_list_virus[i])
        #os.remove(file)
        bRet = False
    i+=1
# Out:
# All_2001/virus/f20b02fea8bd17ae3b7501454cf385e4f5b64e65b4a7618a96aa09e708c89613.asm8
# All_2001/virus/96493e539ea25d6540aa51359d874d55a1439d54404681978c065a43ab64f325.asmVT2
# All_2001/virus/c5bff578241fc5656722409e1e5653c667ffb8ca48fd36cddc4c9b3dcfe69d39.asm8
# All_2001/virus/00d980db5d7b609d48fac29bcb7f55d0bc95f5955ff711bd81d7a9a3540658b4.asm8
# All_2001/virus/87b4a80ede9b5cb4dd9f7628a344a352452d511adfdeb64de522fa7456ebdfd7.asmVT
# All_2001/virus/b128af5e55eb803dcadd180d73c02b1d87ebaa34310d64b014a2a8c5471c0747.asmVT2
# All_2001/virus/b347fbd1444f920edc9927730e0732396753270d466c7ac327ac549bf2b7ed00.asm8
# All_2001/virus/1f89b1f395618224bb37c78ada52c36c3466bb2165093222ddee3ea01daa420a.asm6
# All_2001/virus/23c860ec08f388f4b7c89f8d71dd9ef9ab0d5af8027fbc1c1df4c9ba4605eb9d.asm8
# All_2001/virus/d392a9b213c3533c4a9961c7de676f68b45e3797d34083acd2443e61609d31c4.asmVT2
# All_2001/virus/f1867c2a170250d69d020b4dafa24662dfb82e2e226275a75bfd232c12a63f7d.asmVT2
# ...

# %%
import os
file_list_clean = os.listdir('All_2001/clean')
file_list_virus = os.listdir('All_2001/virus')
DirectoryClean = 'All_2001/clean'
DirectoryVirus = 'All_2001/virus'
bRet = False
i=0
for b in range(len(file_list_virus)):
    with open(DirectoryVirus+'/'+file_list_virus[i], 'r',encoding='utf-8') as file_to_check:
        # read contents of the file       
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(DirectoryVirus+'/'+file_list_virus[i])
        #os.remove(file)
        bRet = False
    i+=1

# %%
len(MD5FullFile)
# Out:
# 8310

# %%
input_dir = Path('3/clean')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()for layer in model_load.layers:
    print("test")
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 11839

# %%
input_dir = Path('4/clean')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 12628

# %%
input_dir = Path('All_clean new')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 27087

# %%
input_dir = Path('All_clean new/Extract 30')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 27087

# %%
MD5FullFileVirus1 = ["11111111111111111111"]

# %%
DirectoryMove = 'Move/virus'
import ntpath

# %%
MD5FullFileVirus5 = ["11111111111111111111"]
input_dir = Path('All_virus new')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(file)
        fileName = ntpath.basename(file)
        os.rename(file, DirectoryMove+'/'+fileName)
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFileVirus5.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 27087

# %%
len(MD5FullFileVirus5)
# Out:
# 46196

# %%
MD5FullFileVirus2 = ["11111111111111111111"]
input_dir = Path('2/virus')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(file)
        fileName = ntpath.basename(file)
        os.rename(file, DirectoryMove+'/'+fileName)
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFileVirus2.append(md5_returned)
# Out:
# 2/virus/c3f5e0007275f343d8c3b54f1ffe94d4231d34c807edf1ae3fb3437bd64194a9.asm
# 2/virus/c3e2d1e068452521c4e98f680bcfa05157a4118890bb83cf2fd1ef45811d5ad7.asm
# 2/virus/b56d4603abdb8887308ddd3ecf76dba1be9288fe7d3f42968267a9e37c94a123.asm
# 2/virus/06de6a9d77c502d15838de923e4fd1438a7eeaf88e2b4962b70c8c7ac208e25b.asm
# 2/virus/928677e7aafd57e9ffaeaa4d8201e04ca28f4057fa3830c5d63d6ddb72c89826.asm
# 2/virus/89b4bc6547a27906eee2aaaee87512e604ec7c2ce9f2264723f07b845db5d06f.asm
# 2/virus/472d8d2e1994121ea2a24586c5c9118ce88beae883ab72703ede80ac0dc149f5.asm
# 2/virus/0ac89b218c6d08fab510cd8854e52c80a29b9fb7c5178e0a15860c79144b3b81.asm
# 2/virus/9250548612a2911660c359603cc8444e995e015fd735b72a3532c5622e9dc78b.asm
# 2/virus/258cbbacdf860c87bfd1bb0abc76ac6bb434b6a9fcd755a7a652cc02a2632795.asm
# 2/virus/5384c20f9dbc3a7369ffa85931b9b5a192ed40e3bc9d725aaca3a7e6ef51b6dc.asm
# 2/virus/ad4a82da6877b0597ed4ff10af2a2571d727ce4b6dc2accf961b7b7c408c1846.asm
# ...

# %%
len(MD5FullFile)
# Out:
# 27087

# %%
len(MD5FullFileVirus2)
# Out:
# 4545

# %%
MD5FullFileVirus3 = ["11111111111111111111"]
input_dir = Path('3/virus')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        print(file)
        fileName = ntpath.basename(file)
        os.rename(file, DirectoryMove+'/'+fileName)
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFileVirus3.append(md5_returned)
# Out:
# 3/virus/f986e0d5d5ce33ad22ca6039de80ada0e06829425675835ed8bb8a454e39b30e.asm
# 3/virus/6b1c3bc05409882237a8d7f180b6ba7e6e1986ef31d45f9a61270aadc22d1a71.asm
# 3/virus/b1467be8c68727b06551a49d3337d70639bf82e235b3f32bff308d4ba73a4a5f.asm
# 3/virus/32d969f6b215521181d12e3c704e6f6201e9f47e9cf2a63f1dc6a19ea20c5a97.asm
# 3/virus/90146fbd2d21580908a31693024def52d2626889754876e928daae852c1d673c.asm
# 3/virus/bb88120c3e6fdaf4cbabf397b3a8472fab27867c793a358481862c46dfc75e12.asm
# 3/virus/eef67a06a6e6a34f848e2c5d10d4ab26cddbcf06dc9be9838ac3323d47a0e601.asm
# 3/virus/48230a15a46ff73896d59de01351ddd4e89beacf64f6483fab94291fbeee055c.asm
# 3/virus/c4029c7cc9375d5aacba350875eea5c2673f686e388976c34f36c7bc8ed70234.asm
# 3/virus/45132c1079f66292cdcee3c2878dc1f578ed8d12ed1380200d19972886bb984d.asm
# 3/virus/82ec4627ec273f14597e2b015661e73656bd6e8634d85a0873faac879cd5f196.asm
# 3/virus/396d30d92552982a85620a6b62943d03853c4d16f76cf6a813a180e9513decb8.asm
# ...

# %%
len(MD5FullFile)
# Out:
# 27087

# %%
len(MD5FullFileVirus3)
# Out:
# 6168

# %%
input_dir = Path('/home/amc/Documents/ChienND/Data VR 0711/4')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 26267

# %%
input_dir = Path('/home/amc/Documents/ChienND/Data VR 0711/5')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 27599

# %%
input_dir = Path('/home/amc/Documents/ChienND/Data VR 0711/8')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 29401

# %%
input_dir = Path('/home/amc/Documents/ChienND/Data VR 0711/9')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 30497

# %%
with open('MD5_file_all_clean.txt', 'w') as f:
    for item in MD5FullFile:
        f.write("%s," % item)

# %%
input_dir = Path('2')
data_files = input_dir.glob('**/*.asm')
bRet = False
for file in data_files:
    with open(file) as file_to_check:
        # read contents of the file
        data = file_to_check.read()    
        # pipe contents of the file through
        md5_returned = hashlib.md5(data.encode('utf-8')).hexdigest()
        file_to_check.close()
    for md5 in MD5FullFile:
        if md5_returned == md5:
            bRet = True
            break
    if bRet == True:
        #os.remove(file)
        bRet = False
    else:   
        MD5FullFile.append(md5_returned)

# %%
len(MD5FullFile)
# Out:
# 30497
